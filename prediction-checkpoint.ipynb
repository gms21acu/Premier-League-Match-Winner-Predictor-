# %%
import pandas as pd

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.impute import SimpleImputer
from tabulate import tabulate

# %%
df = pd.read_csv("PremierLeague.csv")

# %%
if "Date" in df.columns:
    df["Date"]= pd.to_datetime(df["Date"], errors="coerce")

# %%
y = df[["FullTimeHomeTeamGoals", "FullTimeAwayTeamGoals"]]

# %%
X = df[["HomeTeam", "AwayTeam", "Season", "MatchWeek","B365HomeTeam", "B365Draw", "B365AwayTeam","Date"]]

# %%
X=X.dropna(subset=["Date","MatchWeek"])

# %%
y=y.loc[X.index]

# %%
categorical_features = ["HomeTeam", "AwayTeam", "Season"]

# %%
numeric_features = ["MatchWeek", "B365HomeTeam", "B365Draw", "B365AwayTeam"]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
        ("num", Pipeline(steps=[("imputer",SimpleImputer(strategy="mean")),]),numeric_features)
    ],
    remainder = "drop"
)

# %%
model = MultiOutputRegressor(RandomForestRegressor(n_estimators=200, random_state=42))

# %%
pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("model", model)
])

# %%
train_mask = X["Season"] != "2024-2025"

# %%
predict_mask = X["Season"] == "2024-2025"

# %%
X_train, y_train = X[train_mask], y[train_mask]

# %%
X_pred,y_true = X[predict_mask], y[predict_mask]

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['HomeTeam', 'AwayTeam',
#                                                    'Season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['MatchWeek', 'B365HomeTeam',
#                                                    'B365Draw',
#                                                    'B365AwayTeam'])])),
#                 ('model',
#                  MultiOutputRegressor(estimator=RandomForestRegressor(n_estimators=200,
#                                                                       random_state=42)))])

# %%
y_pred=pipeline.predict(X_pred)

# %%
pred_home = y_pred[:,0].round().astype(int)

# %%
pred_away = y_pred[:,1].round().astype(int)

# %%
def result_label(home, away):
    if home > away:
        return "Home Win"
    elif home<away:
        return "Äway Win"
    else:
        return "Draw"

# %%
actual_results = [result_label(h,a) for h, a in zip(y_true["FullTimeHomeTeamGoals"], y_true["FullTimeAwayTeamGoals"])]

# %%
predicted_results = [result_label(h,a) for h,a in zip(pred_home, pred_away)]

# %%
predictions = pd.DataFrame({
    "Date": X_pred["Date"].dt.strftime("%Y-%m-%d"),
    "Match Week": X_pred["MatchWeek"].values,
    "Home Team":X_pred["HomeTeam"].values,
    "Away Team":X_pred["AwayTeam"].values,
    "Actual Result": actual_results,
    "Predicted Result": predicted_results,
    "Actual Home Goals": y_true["FullTimeHomeTeamGoals"].values,
    "Actual Away Goals": y_true["FullTimeAwayTeamGoals"].values,
    "Pred Home Goals": pred_home,
    "Pred Away Goals": pred_away,
})

# %%
predictions["Correct"] = predictions["Actual Result"] == predictions["Predicted Result"]

# %%
predictions["Actual Score"] = (
    predictions["Actual Home Goals"].astype(str) + "-" + predictions["Actual Away Goals"].astype(str)
)

# %%
predictions["Predicted Score"] = (
    predictions["Pred Home Goals"].astype(str) + "-" + predictions["Pred Away Goals"].astype(str)
)

# %%
pred_table = predictions[[
    "Date","Match Week", "Home Team","Away Team","Actual Result","Predicted Result","Actual Score","Predicted Score"
]].sort_values(by="Match Week")

# %%
print("\n2024-2025 Season EPL Predictions")
print(tabulate(pred_table,headers="keys",tablefmt="grid",showindex=False))
# Out:
# 2024-2025 Season EPL Predictions
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
#
| 1-1               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-20 |           37 | Man City       | Bournemouth    | Home Win        | Home Win           | 3-1            | 3-1               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-16 |           37 | Aston Villa    | Tottenham      | Home Win        | Home Win           | 2-0            | 2-1               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-16 |           37 | Chelsea        | Man United     | Home Win        | Home Win           | 1-0            | 2-1               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-18 |           37 | Everton        | Southampton    | Home Win        | Home Win           | 2-0            | 2-0               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-18 |           37 | West Ham       | Nott'm Forest  | Äway Win        | Home Win           | 1-2            | 2-1               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-18 |           37 | Leicester      | Ipswich        | Home Win        | Draw               | 2-0            | 1-1               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-18 |           37 | Brentford      | Fulham         | Äway Win        | Home Win           | 2-3            | 2-1               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Ipswich        | West Ham       | Äway Win        | Äway Win           | 1-3            | 1-2               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Liverpool      | Crystal Palace | Draw            | Draw               | 1-1            | 2-2               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Wolves         | Brentford      | Draw            | Äway Win           | 1-1            | 1-2               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Tottenham      | Brighton       | Äway Win        | Draw               | 1-4            | 2-2               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Bournemouth    | Leicester      | Home Win        | Draw               | 2-0            | 2-2               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Fulham         | Man City       | Äway Win        | Äway Win           | 0-2            | 1-2               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Southampton    | Arsenal        | Äway Win        | Äway Win           | 1-2            | 1-3               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Nott'm Forest  | Chelsea        | Äway Win        | Äway Win           | 0-1            | 1-2               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Newcastle      | Everton        | Äway Win        | Home Win           | 0-1            | 2-1               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+
# | 2025-05-25 |           38 | Man United     | Aston Villa    | Home Win        | Draw               | 2-0            | 2-2               |
# +------------+--------------+----------------+----------------+-----------------+--------------------+----------------+-------------------+

# %%
weekly_accuracy = predictions.groupby("Match Week")["Correct"].mean()*100

# %%
print("\nWeekly Accuracy")
for week, acc in weekly_accuracy.items():
    print(f"Match Week {week}: {acc:.2f}%")
# Out:
# Weekly Accuracy
# Match Week 1: 50.00%
# Match Week 2: 80.00%
# Match Week 3: 60.00%
# Match Week 4: 70.00%
# Match Week 5: 50.00%
# Match Week 6: 40.00%
# Match Week 7: 60.00%
# Match Week 8: 40.00%
# Match Week 9: 40.00%
# Match Week 10: 50.00%
# Match Week 11: 60.00%
# Match Week 12: 40.00%
# Match Week 13: 70.00%
# Match Week 14: 60.00%
# Match Week 15: 20.00%
# Match Week 16: 20.00%
# Match Week 17: 50.00%
# Match Week 18: 50.00%
# Match Week 19: 40.00%
# Match Week 20: 40.00%
# Match Week 21: 70.00%
# Match Week 22: 50.00%
# Match Week 23: 30.00%
# Match Week 24: 30.00%
# Match Week 25: 50.00%
# Match Week 26: 50.00%
# Match Week 27: 60.00%
# Match Week 28: 50.00%
# Match Week 29: 30.00%
# Match Week 30: 60.00%
# Match Week 31: 50.00%
# Match Week 32: 60.00%
# Match Week 33: 30.00%
# Match Week 34: 80.00%
# Match Week 35: 40.00%
# Match Week 36: 20.00%
# Match Week 37: 40.00%
# Match Week 38: 50.00%

# %%
total_accuracy = predictions["Correct"].mean()*100

# %%
print(f"\nTotal Prediction Accuracy: {total_accuracy:.2f}%")
# Out:
# Total Prediction Accuracy: 48.42%

# %%
predictions.to_csv("PremierLeauge_2024-2025_Prediction.csv",index=False)
